# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "proceeding": {
        "file" : "proceedings.bib",
        "venuekey": "booktitle",
        "venue-pretext": "In the proceedings of ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    },
    "journal":{
        "file": "pubs.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w', encoding="utf-8") as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# SUCESSFULLY PARSED bouquillard:hal-04458185: " {Engraving Oriented Joint Estimation of Pitch Spelling and L ... "
# SUCESSFULLY PARSED amagasu:hal-04458252: " {Tokenization of MIDI Sequences for Transcription}  "
# SUCESSFULLY PARSED karystinaios:hal-04458240: " {8+8=4: Formalizing Time Units to Handle Symbolic Music Dura ... "
# SUCESSFULLY PARSED digard:hal-03815760: " {Automated Transcription of Electronic Drumkits}  "
# SUCESSFULLY PARSED jacquemard:hal-03647675: " {Symbolic Weighted Language Models, Quantitative Parsing and ... "
# WARNING Missing Expected Field 'booktitle' from entry digard:hal-03847232: " {MIDI To Score Automated Drum  ... "
# SUCESSFULLY PARSED foscarin:hal-02929324: " {ASAP: a dataset of aligned scores and performances for pian ... "
# SUCESSFULLY PARSED foscarin:hal-02267454: " {A diff procedure for music score files}  "
# SUCESSFULLY PARSED foscarin:hal-02309923: " {Computation and Visualization of Differences between two XM ... "
# SUCESSFULLY PARSED donatbouillud:hal-02284258: " {Optimization of audio graphs by resampling}  "
# SUCESSFULLY PARSED foscarin:hal-01988990: " {A Parse-based Framework for Coupled Rhythm Quantization and ... "
# SUCESSFULLY PARSED foscarin:hal-02024437: " {Modeling and Learning Rhythm Structure}  "
# SUCESSFULLY PARSED foscarin:hal-01895171: " {Gioqoso, an online Quality Assessment Tool for Music Notati ... "
# SUCESSFULLY PARSED foscarin:hal-01791404: " {{\'E}valuation de la correction rythmique des partitions nu ... "
# WARNING Missing Expected Field 'booktitle' from entry foscarin:hal-01989029: " {Evaluating musical score diff ... "
# SUCESSFULLY PARSED jacquemard:hal-01472646: " {Interactive Music Transcription based on Rhythm Tree Langua ... "
# SUCESSFULLY PARSED jacquemard:hal-01403982: " {Generating equivalent rhythmic notations based on rhythm tr ... "
# SUCESSFULLY PARSED ycart:hal-01315689: " {A Supervised Approach for Rhythm Transcription Based on Tre ... "
# SUCESSFULLY PARSED jacquemard:hal-01367535: " {Some results on confluence: decision and what to do without ... "
# SUCESSFULLY PARSED ycart:hal-01298806: " {Une approche interactive pour la transcription rythmique da ... "
# SUCESSFULLY PARSED jacquemard:hal-01149319: " {Term Rewriting with Prefix Context Constraints and Bottom-U ... "
# SUCESSFULLY PARSED jacquemard:hal-01138642: " {A Structural Theory of Rhythm Notation based on Tree Repres ... "
# SUCESSFULLY PARSED donatbouillud:hal-01105418: " {Towards an Equational Theory of Rhythm Notation}  "
# SUCESSFULLY PARSED poncelet:hal-01097345: " {Model Based Testing of an Interactive Music System}  "
# SUCESSFULLY PARSED bresson:hal-01142022: " {Projet EFFICACE : D{\'e}veloppements et perspectives en com ... "
# SUCESSFULLY PARSED ponceletsanchez:hal-01021617: " {Test Methods for Score-Based Interactive Music Systems}  "
# SUCESSFULLY PARSED jacquemard:hal-01109666: " {Rhythm Tree Rewriting}  "
# WARNING Missing Expected Field 'booktitle' from entry poncelet:hal-01133597: " {Test methods for Score-Based  ... "
# SUCESSFULLY PARSED baudart:hal-00850299: " {A Synchronous Embedding of Antescofo, a Domain-Specific Lan ... "
# SUCESSFULLY PARSED fanchon:hal-00829821: " {Formal Timing Analysis Of Mixed Music Scores}  "
# SUCESSFULLY PARSED jacquemard:hal-00852379: " {Unranked Tree Rewriting and Effective Closures of Languages ... "
# SUCESSFULLY PARSED cont:hal-00787033: " {From Authored to Produced Time in Computer-Musician Interac ... "
# SUCESSFULLY PARSED jacquemard:hal-00767719: " {Rewrite Closure and CF Hedge Automata}  "
# SUCESSFULLY PARSED cont:hal-00718854: " {Correct Automatic Accompaniment Despite Machine Listening o ... "
# SUCESSFULLY PARSED echeveste:hal-00642921: " {Formalisation des relations temporelles dans un contexte d' ... "
# SUCESSFULLY PARSED echeveste:hal-01156639: " {Formalisation des relations temporelles entre une partition ... "
# SUCESSFULLY PARSED jacquemard:hal-00643160: " {Controlled Term Rewriting}  "
# SUCESSFULLY PARSED jacquemard:inria-00578896: " {Multiple Congruence Relations, First-Order Theories on Term ... "
# SUCESSFULLY PARSED abassi:inria-00578884: " {XML Access Control: from XACML to Annotated Schemas}  "
# SUCESSFULLY PARSED jacquemard:inria-00578916: " {Rewrite-Based Verification of XML Updates}  "
# SUCESSFULLY PARSED barguno:inria-00578901: " {The Emptiness Problem for Tree Automata with Global Constra ... "
# SUCESSFULLY PARSED benyoussef:inria-00578926: " {Automatic Verification of Conformance of Firewall Configura ... "
# SUCESSFULLY PARSED godoy:inria-00578959: " {Unique Normalization for Shallow TRS}  "
# SUCESSFULLY PARSED jacquemard:inria-00579001: " {Rigid Tree Automata}  "
# SUCESSFULLY PARSED bouhoula:inria-00579004: " {Automated Induction with Constrained Tree Automata}  "
# SUCESSFULLY PARSED gascon:inria-00578966: " {Closure of Tree Automata Languages under Innermost Rewritin ... "
# SUCESSFULLY PARSED jacquemard:inria-00329803: " {Closure of Hedge-Automata Languages by Hedge Rewriting}  "
# SUCESSFULLY PARSED bouhoula:inria-00579015: " {Verifying Regular Trace Properties of Security Protocols wi ... "
# SUCESSFULLY PARSED comonlundh:inria-00579009: " {Tree Automata with Memory, Visibility and Structural Constr ... "
# WARNING Missing Expected Field 'booktitle' from entry filiot:hal-00840959: " {Tree Automata with Constraint ... "
# SUCESSFULLY PARSED giraud:hal-01857267: " {Weighted Automata Computation of Edit Distances with Consol ... "
# SUCESSFULLY PARSED poncelet:hal-01314969: " {Model-Based Testing for Building Reliable Realtime Interact ... "
# SUCESSFULLY PARSED jacquemard:hal-01274035: " {An Automatic Test Framework for Interactive Music Systems}  "
# SUCESSFULLY PARSED jacquemard:hal-01426626: " {One-variable context-free hedge automata}  "
# SUCESSFULLY PARSED jacquemard:hal-00769249: " {FO2(<,+1,~) on data trees, data tree automata and branching ... "
# SUCESSFULLY PARSED echeveste:hal-00854719: " {Operational semantics of a domain specific language for rea ... "
# SUCESSFULLY PARSED barguno:hal-00852382: " {Decidable Classes of Tree Automata Mixing Local and Global  ... "
# SUCESSFULLY PARSED cont:hal-00753014: " {Antescofo {\`a} l'avant-garde de l'informatique musicale}  "
# SUCESSFULLY PARSED bouhoula:hal-00643136: " {Sufficient Completeness Verification for Conditional and Co ... "
# SUCESSFULLY PARSED jacquemard:inria-00578820: " {Rigid Tree Automata and Applications}  "
# SUCESSFULLY PARSED comonlundh:inria-00578844: " {Visibly Tree Automata with Memory and Constraints}  "
# SUCESSFULLY PARSED jacquemard:inria-00329693: " {Tree automata with equality constraints modulo equational t ... "
